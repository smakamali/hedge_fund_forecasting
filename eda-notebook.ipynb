# %% [markdown]
# # EDA: Time Series Forecasting
#
# Exploratory analysis of `train.parquet`: sub_category, code, sub_code, horizon, ts_index vs y_target. See `EDA_OBSERVATIONS.md` for documented findings.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_rows', 1000)

# %%
pdf = pd.read_parquet('./train.parquet')

# %% [markdown]
# ## EDA: sub_category, code, sub_code, horizon, ts_index vs y_target
#
# Exploring relationships between identifiers, time, and target to inform preprocessing and modeling.

# %%
# 1) Cardinality and value counts
cols_meta = ['sub_category', 'code', 'sub_code', 'horizon', 'ts_index']
for c in cols_meta:
    n = pdf[c].nunique()
    print(f"{c}: {n} unique values")
print()
# Value counts for categoricals
print("--- sub_category ---")
print(pdf['sub_category'].value_counts().sort_index())
print("\n--- horizon ---")
print(pdf['horizon'].value_counts().sort_index())
print("\n--- ts_index range ---")
print(f"min={pdf['ts_index'].min()}, max={pdf['ts_index'].max()}, span={pdf['ts_index'].max() - pdf['ts_index'].min()}")
# Out:
# sub_category: 5 unique values
# code: 23 unique values
# sub_code: 180 unique values
# horizon: 4 unique values
# ts_index: 3601 unique values
#
# --- sub_category ---
# sub_category
# DPPUO5X2    1072705
# NQ58FVQM    1067164
# PHHHVYZI    1067164
# PZ9S1Z4V    1074239
# V8BKY1IV    1056142
# Name: count, dtype: int64
#
# --- horizon ---
# horizon
# 1     1394653
# 3     1385816
# 10    1337236
# 25    1219709
# Name: count, dtype: int64
#
# --- ts_index range ---
# min=1, max=3601, span=3600

# %%
# 2) y_target distribution (overall and by categorical)
print("y_target overall:")
print(pdf['y_target'].describe())
print("\n--- y_target by sub_category (mean, std, count) ---")
by_sub = pdf.groupby('sub_category')['y_target'].agg(['mean', 'std', 'count'])
print(by_sub.sort_values('mean'))
print("\n--- y_target by horizon (mean, std, count) ---")
by_hor = pdf.groupby('horizon')['y_target'].agg(['mean', 'std', 'count'])
print(by_hor.sort_values('mean'))
# Out:
# y_target overall:
# count    5.337414e+06
# mean    -6.659048e-01
# std      3.252764e+01
# min     -2.201882e+03
# 25%     -1.290776e-01
# 50%     -5.774818e-04
# 75%      5.106807e-02
# max      2.314411e+03
# Name: y_target, dtype: float64
#
# --- y_target by sub_category (mean, std, count) ---
#                   mean        std    count
# sub_category
# PHHHVYZI     -1.446897  53.455295  1067164
# PZ9S1Z4V     -1.217609  28.187398  1074239
# NQ58FVQM     -0.997217  19.832982  1067164
# DPPUO5X2     -0.180652  29.266238  1072705
# V8BKY1IV      0.526302  19.532539  1056142
#
# --- y_target by horizon (mean, std, count) ---
#              mean        std    count
# horizon
# 25      -1.681878  52.823280  1219709
# 10      -0.775965  33.842065  1337236
# 3       -0.252409  19.361190  1385816
# 1       -0.082721  11.699685  1394653

# %%
# 3) y_target by code (top/bottom by mean)
by_code = pdf.groupby('code')['y_target'].agg(['mean', 'std', 'count']).sort_values('mean')
print("Codes with lowest mean y_target:")
print(by_code.head(8))
print("\nCodes with highest mean y_target:")
print(by_code.tail(8))
print("\n--- y_target by sub_code (sample: 10 with most rows) ---")
sub_code_counts = pdf.groupby('sub_code').size().sort_values(ascending=False)
top_sub_codes = sub_code_counts.head(10).index.tolist()
by_subcode = pdf[pdf['sub_code'].isin(top_sub_codes)].groupby('sub_code')['y_target'].agg(['mean', 'std', 'count'])
print(by_subcode)
# Out:
# Codes with lowest mean y_target:
#                mean         std   count
# code
# W4S29LF4 -10.952807  142.610537  193977
# QAQDDTPJ  -6.299555  109.241238  130876
# 10BAVIDU  -0.977455   14.637540  134886
# 2RBMUWP1  -0.941983   15.612861  176409
# WH61ASEA  -0.659445   12.368094   74291
# K7Y1TTAH  -0.595550    6.807219  324479
# X9BZ68VQ  -0.166515    7.676776  209261
# OSJL3A7Y  -0.041594    1.879662  564790
#
# Codes with highest mean y_target:
#               mean       std   count
# code
# SJZP0OVU -0.000056  0.002014  237283
# 83EG83KQ  0.000018  0.000919  118694
# 1HEMHZK2  0.000137  0.007241  293024
# VFWIFJPS  0.000410  0.013920  318517
# 6LB028J8  0.003549  0.221563  484082
# 84J8BJFZ  0.007242  0.403669  234375
# 660DZME0  0.008396  2.005410  264071
# HYOGKLEV  0.018635  0.213236   92259
#
# --- y_target by sub_code (sample: 10 with most rows) ---
#               mean        std  count
# sub_code
# 69SD4Y3A  2.427077  38.593799  69521
# 9G2OWCRE -1.217303  35.962681  65507
# CUXV51HW  1.637894  38.513773  60184
# DYJUJX3J  0.055314  43.227273  64163
# FECMBC0A -1.106235  31.444938  59645
# J7UUOGYG -3.738695  42.563951  66946
# OYJGNSQK -1.349889  24.739147  69390
# PCXKOBIH -1.530173  27.594688  68383
# TI04KMOC  0.536488  40.939494  68844
# XT8JWYHT  1.746321  38.640912  68515

# %%
# 4) Hierarchy: code -> sub_code -> sub_category
# How many sub_codes per code? How many codes per sub_category?
print("Sub_codes per code:")
print(pdf.groupby('code')['sub_code'].nunique().describe())
print("\nCodes per sub_category:")
print(pdf.groupby('sub_category')['code'].nunique())
print("\nSub_codes per sub_category:")
print(pdf.groupby('sub_category')['sub_code'].nunique())
# Out:
# Sub_codes per code:
# count     23.000000
# mean      80.695652
# std       33.088634
# min       39.000000
# 25%       57.000000
# 50%       72.000000
# 75%      102.500000
# max      176.000000
# Name: sub_code, dtype: float64
#
# Codes per sub_category:
# sub_category
# DPPUO5X2    23
# NQ58FVQM    23
# PHHHVYZI    23
# PZ9S1Z4V    23
# V8BKY1IV    23
# Name: code, dtype: int64
#
# Sub_codes per sub_category:
# sub_category
# DPPUO5X2    180
# NQ58FVQM    180
# PHHHVYZI    180
# PZ9S1Z4V    180
# V8BKY1IV    180
# Name: sub_code, dtype: int64

# %%
# 5) Cross-tabs: mean y_target by (sub_category, horizon) and (code, horizon)
print("Mean y_target by (sub_category, horizon):")
ct_sc_h = pdf.pivot_table(values='y_target', index='sub_category', columns='horizon', aggfunc='mean')
print(ct_sc_h.round(6))
print("\nMean y_target by (code, horizon) - sample first 5 codes:")
codes_sample = pdf['code'].unique()[:5]
ct_c_h = pdf[pdf['code'].isin(codes_sample)].pivot_table(values='y_target', index='code', columns='horizon', aggfunc='mean')
print(ct_c_h.round(6))
# Out:
# Mean y_target by (sub_category, horizon):
# horizon             1         3         10        25
# sub_category
# DPPUO5X2     -0.073170 -0.176608 -0.263271 -0.217943
# NQ58FVQM     -0.057507 -0.222511 -1.039921 -2.905709
# PHHHVYZI     -0.204334 -0.602170 -1.678069 -3.574588
# PZ9S1Z4V     -0.139709 -0.419614 -1.350344 -3.222805
# V8BKY1IV      0.063709  0.165175  0.463132  1.526316
#
# Mean y_target by (code, horizon) - sample first 5 codes:
# horizon         1         3         10         25
# code
# 2RBMUWP1 -0.136989 -0.350330 -1.055789  -2.392555
# 660DZME0 -0.000061  0.004399  0.012248   0.018476
# OSJL3A7Y -0.006584 -0.009801 -0.038823  -0.121341
# QAQDDTPJ -0.655491 -2.110390 -7.161738 -16.356842
# W2MW3G2L -0.002644 -0.006819 -0.025027  -0.061215

# %%
code_arr = pdf['code'].unique()
code_arr
# Out:
# <ArrowStringArray>
# ['W2MW3G2L', 'OSJL3A7Y', '660DZME0', '2RBMUWP1', 'QAQDDTPJ', 'W4S29LF4',
#  '10BAVIDU', 'MLAAMU3K', 'K7Y1TTAH', 'VFWIFJPS', 'CXEQN6KB', '1HEMHZK2',
#  'MRV5UON2', 'HYOGKLEV', 'X9BZ68VQ', 'WH61ASEA', '6LB028J8', 'EP12UF2K',
#  'K8I5QG74', 'SJZP0OVU', '4KUR2ZOZ', '84J8BJFZ', '83EG83KQ']
# Length: 23, dtype: str

# %%
code_idx = 4
unique_combos = pdf[['code', 'sub_code', 'sub_category']][pdf['code'] == code_arr[code_idx]].drop_duplicates().reset_index(drop=True)
print("Unique combinations of code, sub_code, sub_category:", unique_combos.shape[0])
# Out:
# Unique combinations of code, sub_code, sub_category: 195

# %%
# 6) ts_index vs y_target: temporal coverage and rolling mean by group
# Sample one (code, sub_code, sub_category) and plot y_target over ts_index for each horizon
import matplotlib.pyplot as plt
combo_idx = 1
sample_code = unique_combos['code'].iloc[combo_idx]
sample_sub = unique_combos['sub_code'].iloc[combo_idx]
sample_cat = unique_combos['sub_category'].iloc[combo_idx]


mask = (pdf['code'] == sample_code) & (pdf['sub_code'] == sample_sub) & (pdf['sub_category'] == sample_cat)
sample_df = pdf.loc[mask].sort_values('ts_index')
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
for ax, (h, grp) in zip(axes.flat, sample_df.groupby('horizon')):
    grp = grp.sort_values('ts_index')
    ax.plot(grp['ts_index'], grp['y_target'], alpha=0.7, label='y_target')
    ax.set_title(f'horizon={h}')
    ax.set_xlabel('ts_index')
    ax.legend()
plt.suptitle(f'Entity: {sample_code} / {sample_sub} / {sample_cat}')
plt.tight_layout()
plt.show()

# %%
# 7) Global: mean y_target over ts_index (binned) to see trend
bins = pd.qcut(pdf['ts_index'], q=20, duplicates='drop')
ts_agg = pdf.groupby(bins).agg({'y_target': 'mean', 'ts_index': 'mean', 'weight': 'sum'})
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(ts_agg['ts_index'], ts_agg['y_target'], marker='o', markersize=4)
ax.set_xlabel('ts_index (bin mean)')
ax.set_ylabel('Mean y_target')
ax.set_title('Mean y_target across time (global, 20 quantile bins)')
plt.tight_layout()
plt.show()

# %%
# 8) Box plots: y_target by sub_category and by horizon
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
# Clip extreme y_target for visibility
y_clip = pdf['y_target'].clip(-50, 50)
pdf_temp = pdf.assign(y_clip=y_clip)
pdf_temp.boxplot(column='y_clip', by='sub_category', ax=axes[0])
axes[0].set_title('y_target (clipped ±50) by sub_category')
axes[0].set_xlabel('sub_category')
pdf_temp.boxplot(column='y_clip', by='horizon', ax=axes[1])
axes[1].set_title('y_target (clipped ±50) by horizon')
axes[1].set_xlabel('horizon')
plt.suptitle('')
plt.tight_layout()
plt.show()

# %%
# 9) Heatmap: mean y_target by (sub_category, horizon)
import seaborn as sns
ct = pdf.pivot_table(values='y_target', index='sub_category', columns='horizon', aggfunc='mean')
sns.heatmap(ct, annot=True, fmt='.3f', cmap='RdBu_r', center=0)
plt.title('Mean y_target by sub_category × horizon')
plt.tight_layout()
plt.show()

# %%
# 10) Row counts: how many (code, sub_code, sub_category, horizon) combinations per ts_index?
# And distribution of ts_index counts per entity
entity = pdf.groupby(['code', 'sub_code', 'sub_category', 'horizon']).size()
print("Rows per (code, sub_code, sub_category, horizon):")
print(entity.describe())
print("\nTs_index coverage per entity (nunique ts_index):")
ts_per_entity = pdf.groupby(['code', 'sub_code', 'sub_category', 'horizon'])['ts_index'].nunique()
print(ts_per_entity.describe())
# Out:
# Rows per (code, sub_code, sub_category, horizon):
# count    36923.000000
# mean       144.555264
# std         56.770160
# min          1.000000
# 25%        104.000000
# 50%        166.000000
# 75%        194.000000
# max        213.000000
# dtype: float64
#
# Ts_index coverage per entity (nunique ts_index):
# count    36923.000000
# mean       144.555264
# std         56.770160
# min          1.000000
# 25%        104.000000
# 50%        166.000000
# 75%        194.000000
# max        213.000000
# Name: ts_index, dtype: float64

# %%
# Numerical histograms for ALL features (detailed, for distribution analysis and transformation planning)
import numpy as np
from scipy import stats

def print_elaborate_histogram(col, data, bins=50):
    """Print detailed distribution summary for feature transformation planning."""
    data_clean = data.dropna()
    counts, bin_edges = np.histogram(data_clean, bins=bins)
    
    # Basic stats
    mean = data_clean.mean()
    median = data_clean.median()
    std = data_clean.std()
    min_val, max_val = data_clean.min(), data_clean.max()
    
    # Shape: skewness and kurtosis (for distribution type and tail behavior)
    skew = stats.skew(data_clean)
    kurt = stats.kurtosis(data_clean)  # excess kurtosis (normal=0)
    
    # Quantiles
    q01, q05, q95, q99 = data_clean.quantile([0.01, 0.05, 0.95, 0.99])
    
    # Outlier info: % outside [Q05, Q95]
    pct_extreme = ((data_clean < q05) | (data_clean > q95)).mean() * 100
    
    print(f"=== {col} (n={len(data_clean)}, bins={bins}) ===")
    print(f"  Range:      [{min_val:.6g}, {max_val:.6g}]")
    print(f"  Mean:       {mean:.6g},  Median: {median:.6g},  Std: {std:.6g}")
    print(f"  Skewness:   {skew:.4f},  Kurtosis: {kurt:.4f}  (skew>0 → right tail; kurt>0 → heavy tails)")
    print(f"  Quantiles:  Q01={q01:.6g}, Q05={q05:.6g}, Q95={q95:.6g}, Q99={q99:.6g}")
    print(f"  Extreme:    {pct_extreme:.2f}% outside [Q05, Q95]")
    print(f"  Histogram bin_edges (first 5): {bin_edges[:5].round(4).tolist()}")
    print(f"            bin_edges (last 5):  {bin_edges[-5:].round(4).tolist()}")
    print(f"  Histogram counts (first 5):    {counts[:5].tolist()}")
    print(f"            counts (last 5):     {counts[-5:].tolist()}")
    print(f"  Histogram count_sum: {counts.sum()},  count_min: {counts.min()},  count_max: {counts.max()}")
    print()

# Run for ALL numeric columns
numeric_cols = [c for c in pdf.columns if pd.api.types.is_numeric_dtype(pdf[c])]
print(f"Generating elaborate histograms for {len(numeric_cols)} numeric columns...\n")
for col in numeric_cols:
    print_elaborate_histogram(col, pdf[col], bins=50)
# Out:
# Generating elaborate histograms for 90 numeric columns...
#
# === horizon (n=5337414, bins=50) ===
#   Range:      [1, 25]
#   Mean:       9.25864,  Median: 3,  Std: 9.20625
#   Skewness:   0.8723,  Kurtosis: -0.8220  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=1, Q05=1, Q95=25, Q99=25
#   Extreme:    0.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [1.0, 1.48, 1.96, 2.44, 2.92]
#             bin_edges (last 5):  [23.08, 23.56, 24.04, 24.52, 25.0]
#   Histogram counts (first 5):    [1394653, 0, 0, 0, 1385816]
#             counts (last 5):     [0, 0, 0, 0, 1219709]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 1394653
#
# === ts_index (n=5337414, bins=50) ===
#   Range:      [1, 3601]
#   Mean:       1963.32,  Median: 2036,  Std: 997.022
#   Skewness:   -0.1813,  Kurtosis: -1.0842  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=66, Q05=273, Q95=3440, Q99=3570
#   Extreme:    9.96% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [1.0, 73.0, 145.0, 217.0, 289.0]
#             bin_edges (last 5):  [3313.0, 3385.0, 3457.0, 3529.0, 3601.0]
#   Histogram counts (first 5):    [59486, 76378, 73092, 74616, 77374]
#             counts (last 5):     [117735, 122266, 129292, 117162, 121015]
#   Histogram count_sum: 5337414,  count_min: 59486,  count_max: 133571
#
# === feature_a (n=5337414, bins=50) ===
#   Range:      [0, 213]
#   Mean:       88.6815,  Median: 84,  Std: 56.0314
#   Skewness:   0.2553,  Kurtosis: -1.0264  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=1, Q05=8, Q95=185, Q99=202
#   Extreme:    9.55% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 4.26, 8.52, 12.78, 17.04]
#             bin_edges (last 5):  [195.96, 200.22, 204.48, 208.74, 213.0]
#   Histogram counts (first 5):    [156853, 129204, 130919, 163977, 132015]
#             counts (last 5):     [49351, 57847, 35308, 24688, 8218]
#   Histogram count_sum: 5337414,  count_min: 8218,  count_max: 164174
#
# === feature_b (n=5337414, bins=50) ===
#   Range:      [0.130004, 17]
#   Mean:       8.56739,  Median: 8.56838,  Std: 4.86998
#   Skewness:   -0.0005,  Kurtosis: -1.1994  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.299317, Q05=0.973435, Q95=16.1571, Q99=16.8319
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.13, 0.4674, 0.8048, 1.1422, 1.4796]
#             bin_edges (last 5):  [15.6504, 15.9878, 16.3252, 16.6626, 17.0]
#   Histogram counts (first 5):    [106515, 107009, 106286, 106748, 107066]
#             counts (last 5):     [107168, 107055, 106739, 106537, 107315]
#   Histogram count_sum: 5337414,  count_min: 105807,  count_max: 107390
#
# === feature_c (n=5337414, bins=50) ===
#   Range:      [0.130002, 17]
#   Mean:       8.56485,  Median: 8.56384,  Std: 4.86941
#   Skewness:   0.0003,  Kurtosis: -1.1998  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.298821, Q05=0.974313, Q95=16.1563, Q99=16.8322
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.13, 0.4674, 0.8048, 1.1422, 1.4796]
#             bin_edges (last 5):  [15.6504, 15.9878, 16.3252, 16.6626, 17.0]
#   Histogram counts (first 5):    [106582, 106400, 106915, 106818, 106920]
#             counts (last 5):     [107047, 106624, 106134, 106379, 107467]
#   Histogram count_sum: 5337414,  count_min: 106134,  count_max: 107467
#
# === feature_d (n=5337414, bins=50) ===
#   Range:      [0.130001, 17]
#   Mean:       8.56506,  Median: 8.56735,  Std: 4.87147
#   Skewness:   -0.0007,  Kurtosis: -1.2004  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.297881, Q05=0.969393, Q95=16.1557, Q99=16.8307
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.13, 0.4674, 0.8048, 1.1422, 1.4796]
#             bin_edges (last 5):  [15.6504, 15.9878, 16.3252, 16.6626, 17.0]
#   Histogram counts (first 5):    [107586, 107064, 107070, 106817, 106803]
#             counts (last 5):     [106976, 107187, 106542, 106767, 106723]
#   Histogram count_sum: 5337414,  count_min: 105766,  count_max: 107586
#
# === feature_e (n=5337414, bins=50) ===
#   Range:      [0.130003, 17]
#   Mean:       8.56293,  Median: 8.56035,  Std: 4.8701
#   Skewness:   0.0008,  Kurtosis: -1.1998  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.299345, Q05=0.973261, Q95=16.1568, Q99=16.832
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.13, 0.4674, 0.8048, 1.1422, 1.4796]
#             bin_edges (last 5):  [15.6504, 15.9878, 16.3252, 16.6626, 17.0]
#   Histogram counts (first 5):    [106994, 107100, 106226, 106884, 107091]
#             counts (last 5):     [106879, 106676, 106726, 106517, 107261]
#   Histogram count_sum: 5337414,  count_min: 106207,  count_max: 107541
#
# === feature_f (n=5337414, bins=50) ===
#   Range:      [0.130008, 17]
#   Mean:       8.56436,  Median: 8.5647,  Std: 4.86888
#   Skewness:   0.0001,  Kurtosis: -1.1999  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.299463, Q05=0.973437, Q95=16.1547, Q99=16.8307
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.13, 0.4674, 0.8048, 1.1422, 1.4796]
#             bin_edges (last 5):  [15.6504, 15.9878, 16.3252, 16.6626, 17.0]
#   Histogram counts (first 5):    [106576, 106800, 106647, 106552, 106607]
#             counts (last 5):     [106346, 106878, 106906, 106249, 106453]
#   Histogram count_sum: 5337414,  count_min: 106241,  count_max: 107347
#
# === feature_g (n=5337414, bins=50) ===
#   Range:      [0.130002, 17]
#   Mean:       8.56652,  Median: 8.56592,  Std: 4.86837
#   Skewness:   -0.0001,  Kurtosis: -1.1998  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.299603, Q05=0.97893, Q95=16.1561, Q99=16.8312
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.13, 0.4674, 0.8048, 1.1422, 1.4796]
#             bin_edges (last 5):  [15.6504, 15.9878, 16.3252, 16.6626, 17.0]
#   Histogram counts (first 5):    [106196, 106146, 106415, 106631, 106528]
#             counts (last 5):     [106391, 106669, 106840, 106329, 106931]
#   Histogram count_sum: 5337414,  count_min: 106046,  count_max: 107347
#
# === feature_h (n=5278949, bins=50) ===
#   Range:      [0, 0.110952]
#   Mean:       0.00591239,  Median: 0.00130803,  Std: 0.00792373
#   Skewness:   1.7563,  Kurtosis: 5.1116  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.000130903, Q05=0.000179735, Q95=0.0211936, Q99=0.0299168
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 0.0022, 0.0044, 0.0067, 0.0089]
#             bin_edges (last 5):  [0.1021, 0.1043, 0.1065, 0.1087, 0.111]
#   Histogram counts (first 5):    [3010896, 256876, 256462, 305658, 187543]
#             counts (last 5):     [40, 40, 40, 40, 40]
#   Histogram count_sum: 5278949,  count_min: 40,  count_max: 3010896
#
# === feature_i (n=5278389, bins=50) ===
#   Range:      [3.91325e-05, 0.0492807]
#   Mean:       0.00540762,  Median: 0.00370902,  Std: 0.00588309
#   Skewness:   1.2992,  Kurtosis: 1.8883  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=6.23104e-05, Q05=0.00011834, Q95=0.0165176, Q99=0.0240263
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 0.001, 0.002, 0.003, 0.004]
#             bin_edges (last 5):  [0.0453, 0.0463, 0.0473, 0.0483, 0.0493]
#   Histogram counts (first 5):    [2129435, 138278, 213939, 217578, 257663]
#             counts (last 5):     [56, 80, 45, 35, 50]
#   Histogram count_sum: 5278389,  count_min: 35,  count_max: 2129435
#
# === feature_j (n=5278949, bins=50) ===
#   Range:      [0, 0.10876]
#   Mean:       0.00166158,  Median: 0.000431147,  Std: 0.00291682
#   Skewness:   6.7203,  Kurtosis: 125.1825  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=3.16201e-06, Q05=2.02318e-05, Q95=0.00648203, Q99=0.0133547
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 0.0022, 0.0044, 0.0065, 0.0087]
#             bin_edges (last 5):  [0.1001, 0.1022, 0.1044, 0.1066, 0.1088]
#   Histogram counts (first 5):    [3990179, 691604, 337197, 129103, 45576]
#             counts (last 5):     [60, 20, 20, 40, 20]
#   Histogram count_sum: 5278949,  count_min: 20,  count_max: 3990179
#
# === feature_k (n=5278389, bins=50) ===
#   Range:      [9.99721e-07, 0.023594]
#   Mean:       0.00247974,  Median: 0.00043485,  Std: 0.0035095
#   Skewness:   1.7820,  Kurtosis: 3.0464  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=7.41327e-06, Q05=3.72651e-05, Q95=0.0100607, Q99=0.014718
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 0.0005, 0.0009, 0.0014, 0.0019]
#             bin_edges (last 5):  [0.0217, 0.0222, 0.0227, 0.0231, 0.0236]
#   Histogram counts (first 5):    [2732859, 343342, 113505, 122334, 131339]
#             counts (last 5):     [426, 480, 375, 265, 115]
#   Histogram count_sum: 5278389,  count_min: 115,  count_max: 2732859
#
# === feature_l (n=5336114, bins=50) ===
#   Range:      [0.0215514, 11.2789]
#   Mean:       0.810025,  Median: 0.263647,  Std: 0.963877
#   Skewness:   1.2602,  Kurtosis: 0.5901  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.037761, Q05=0.049244, Q95=2.72601, Q99=3.58374
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0216, 0.2467, 0.4718, 0.697, 0.9221]
#             bin_edges (last 5):  [10.3783, 10.6035, 10.8286, 11.0537, 11.2789]
#   Histogram counts (first 5):    [2614252, 537470, 331173, 173575, 128477]
#             counts (last 5):     [0, 15, 0, 0, 15]
#   Histogram count_sum: 5336114,  count_min: 0,  count_max: 2614252
#
# === feature_m (n=5299244, bins=50) ===
#   Range:      [0.0291742, 11.2902]
#   Mean:       1.73085,  Median: 1.10711,  Std: 1.78721
#   Skewness:   0.8322,  Kurtosis: -0.4535  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.0389767, Q05=0.0435859, Q95=5.25043, Q99=5.99237
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0292, 0.2544, 0.4796, 0.7048, 0.9301]
#             bin_edges (last 5):  [10.3893, 10.6146, 10.8398, 11.065, 11.2902]
#   Histogram counts (first 5):    [2085619, 1587, 38084, 159973, 469156]
#             counts (last 5):     [15, 5, 0, 0, 20]
#   Histogram count_sum: 5299244,  count_min: 0,  count_max: 2085619
#
# === feature_n (n=5328508, bins=50) ===
#   Range:      [-41.4719, 51.9415]
#   Mean:       0.00298836,  Median: -0.000343467,  Std: 1.40377
#   Skewness:   2.0182,  Kurtosis: 156.8847  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-3.78001, Q05=-0.759166, Q95=0.730425, Q99=4.02639
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-41.4719, -39.6036, -37.7353, -35.8671, -33.9988]
#             bin_edges (last 5):  [44.4684, 46.3367, 48.205, 50.0732, 51.9415]
#   Histogram counts (first 5):    [40, 60, 0, 35, 63]
#             counts (last 5):     [20, 20, 0, 20, 20]
#   Histogram count_sum: 5328508,  count_min: 0,  count_max: 4755578
#
# === feature_o (n=5331156, bins=50) ===
#   Range:      [0, 368.787]
#   Mean:       1.05675,  Median: 0.0045446,  Std: 7.29322
#   Skewness:   13.8633,  Kurtosis: 295.1632  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0, Q95=1.46439, Q99=34.5738
#   Extreme:    4.70% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 7.3757, 14.7515, 22.1272, 29.5029]
#             bin_edges (last 5):  [339.2839, 346.6597, 354.0354, 361.4111, 368.7869]
#   Histogram counts (first 5):    [5170173, 59209, 10976, 34996, 18091]
#             counts (last 5):     [20, 20, 0, 0, 4]
#   Histogram count_sum: 5331156,  count_min: 0,  count_max: 5170173
#
# === feature_p (n=5331052, bins=50) ===
#   Range:      [0, 27.2034]
#   Mean:       0.159498,  Median: 0.0129522,  Std: 0.444224
#   Skewness:   11.5152,  Kurtosis: 314.5656  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0.000153422, Q95=0.776154, Q99=1.80436
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 0.5441, 1.0881, 1.6322, 2.1763]
#             bin_edges (last 5):  [25.0271, 25.5712, 26.1152, 26.6593, 27.2034]
#   Histogram counts (first 5):    [4854613, 334152, 76367, 31277, 13677]
#             counts (last 5):     [20, 0, 0, 0, 10]
#   Histogram count_sum: 5331052,  count_min: 0,  count_max: 4854613
#
# === feature_q (n=5330292, bins=50) ===
#   Range:      [0, 55.9449]
#   Mean:       0.400665,  Median: 0.0141537,  Std: 1.34263
#   Skewness:   10.1987,  Kurtosis: 179.4471  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=5.14233e-05, Q05=0.000167957, Q95=1.85534, Q99=6.03988
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 1.1189, 2.2378, 3.3567, 4.4756]
#             bin_edges (last 5):  [51.4693, 52.5882, 53.7071, 54.826, 55.9449]
#   Histogram counts (first 5):    [4908102, 196943, 83696, 52406, 27459]
#             counts (last 5):     [6, 0, 8, 0, 10]
#   Histogram count_sum: 5330292,  count_min: 0,  count_max: 4908102
#
# === feature_r (n=5328508, bins=50) ===
#   Range:      [0, 74.2926]
#   Mean:       0.507615,  Median: 0.0132605,  Std: 2.52635
#   Skewness:   9.9708,  Kurtosis: 140.7583  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.000212889, Q05=0.000456706, Q95=1.81416, Q99=12.0361
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 1.4859, 2.9717, 4.4576, 5.9434]
#             bin_edges (last 5):  [68.3492, 69.835, 71.3209, 72.8068, 74.2926]
#   Histogram counts (first 5):    [5033301, 82832, 50087, 41395, 24757]
#             counts (last 5):     [150, 60, 0, 20, 25]
#   Histogram count_sum: 5328508,  count_min: 0,  count_max: 5033301
#
# === feature_s (n=5331156, bins=50) ===
#   Range:      [0, 173.714]
#   Mean:       1.57414,  Median: 0.197462,  Std: 5.59031
#   Skewness:   8.7567,  Kurtosis: 113.1449  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0.000672419, Q95=6.13486, Q99=28.5
#   Extreme:    9.99% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 3.4743, 6.9486, 10.4229, 13.8972]
#             bin_edges (last 5):  [159.8173, 163.2916, 166.7659, 170.2402, 173.7145]
#   Histogram counts (first 5):    [4872690, 217914, 69988, 38511, 26696]
#             counts (last 5):     [80, 15, 20, 0, 15]
#   Histogram count_sum: 5331156,  count_min: 0,  count_max: 4872690
#
# === feature_t (n=5331052, bins=50) ===
#   Range:      [0, 222.933]
#   Mean:       5.31005,  Median: 0.242698,  Std: 11.9569
#   Skewness:   4.2685,  Kurtosis: 29.1956  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.000689901, Q05=0.00263529, Q95=28.7539, Q99=55.1261
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 4.4587, 8.9173, 13.376, 17.8347]
#             bin_edges (last 5):  [205.0987, 209.5573, 214.016, 218.4747, 222.9333]
#   Histogram counts (first 5):    [3988896, 378420, 250064, 176783, 135620]
#             counts (last 5):     [100, 0, 20, 20, 80]
#   Histogram count_sum: 5331052,  count_min: 0,  count_max: 3988896
#
# === feature_u (n=5330292, bins=50) ===
#   Range:      [0.000207086, 1419.76]
#   Mean:       22.3697,  Median: 0.0888354,  Std: 91.9751
#   Skewness:   5.7170,  Kurtosis: 37.8265  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.000648449, Q05=0.00205445, Q95=98.2222, Q99=514.799
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0002, 28.3953, 56.7905, 85.1856, 113.5808]
#             bin_edges (last 5):  [1306.1768, 1334.5719, 1362.9671, 1391.3622, 1419.7573]
#   Histogram counts (first 5):    [4753534, 149571, 128675, 58116, 24443]
#             counts (last 5):     [40, 60, 60, 0, 40]
#   Histogram count_sum: 5330292,  count_min: 0,  count_max: 4753534
#
# === feature_v (n=5331260, bins=50) ===
#   Range:      [0.0014788, 263]
#   Mean:       13.0873,  Median: 0.491648,  Std: 35.7433
#   Skewness:   4.3561,  Kurtosis: 20.5061  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.00233751, Q05=0.00515462, Q95=80.7322, Q99=211.985
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0015, 5.2615, 10.5214, 15.7814, 21.0414]
#             bin_edges (last 5):  [241.9605, 247.2204, 252.4804, 257.7404, 263.0004]
#   Histogram counts (first 5):    [3582992, 400271, 447080, 302181, 115904]
#             counts (last 5):     [5290, 8472, 6189, 4812, 2434]
#   Histogram count_sum: 5331260,  count_min: 670,  count_max: 3582992
#
# === feature_w (n=5331230, bins=50) ===
#   Range:      [-900.669, 900.669]
#   Mean:       -1.51026,  Median: 0,  Std: 42.2039
#   Skewness:   -0.3672,  Kurtosis: 45.2317  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-136.119, Q05=-56.8845, Q95=48.0421, Q99=114.994
#   Extreme:    9.97% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-900.6686, -864.6418, -828.6151, -792.5883, -756.5616]
#             bin_edges (last 5):  [756.5616, 792.5883, 828.6151, 864.6418, 900.6686]
#   Histogram counts (first 5):    [24, 40, 60, 120, 40]
#             counts (last 5):     [80, 40, 60, 20, 40]
#   Histogram count_sum: 5331230,  count_min: 20,  count_max: 2595331
#
# === feature_x (n=5331230, bins=50) ===
#   Range:      [-1347.38, 1398.22]
#   Mean:       -3.08907,  Median: -0.144962,  Std: 55.5375
#   Skewness:   -0.9076,  Kurtosis: 81.5907  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-183.831, Q05=-59.4747, Q95=44.2371, Q99=140.517
#   Extreme:    9.96% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-1347.3796, -1292.4676, -1237.5555, -1182.6434, -1127.7313]
#             bin_edges (last 5):  [1178.5759, 1233.4879, 1288.4, 1343.3121, 1398.2242]
#   Histogram counts (first 5):    [60, 15, 4, 4, 12]
#             counts (last 5):     [100, 0, 0, 0, 120]
#   Histogram count_sum: 5331230,  count_min: 0,  count_max: 4405796
#
# === feature_y (n=5331230, bins=50) ===
#   Range:      [-2084.05, 1302.53]
#   Mean:       -15.786,  Median: -0.707447,  Std: 125.392
#   Skewness:   -2.7457,  Kurtosis: 27.9135  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-492.867, Q05=-198.355, Q95=126.306, Q99=278.494
#   Extreme:    9.98% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-2084.0489, -2016.3173, -1948.5857, -1880.8541, -1813.1225]
#             bin_edges (last 5):  [1031.6042, 1099.3358, 1167.0674, 1234.799, 1302.5306]
#   Histogram counts (first 5):    [40, 0, 0, 0, 80]
#             counts (last 5):     [267, 80, 35, 56, 5]
#   Histogram count_sum: 5331230,  count_min: 0,  count_max: 3305269
#
# === feature_z (n=5331230, bins=50) ===
#   Range:      [-1978.6, 1667.68]
#   Mean:       -26.8083,  Median: -1.73742,  Std: 156.562
#   Skewness:   -3.0647,  Kurtosis: 25.7891  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-695.276, Q05=-254.883, Q95=128.427, Q99=306.377
#   Extreme:    9.99% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-1978.6027, -1905.677, -1832.7514, -1759.8258, -1686.9001]
#             bin_edges (last 5):  [1375.9768, 1448.9025, 1521.8281, 1594.7538, 1667.6794]
#   Histogram counts (first 5):    [92, 80, 95, 177, 214]
#             counts (last 5):     [88, 80, 64, 20, 20]
#   Histogram count_sum: 5331230,  count_min: 20,  count_max: 3065717
#
# === feature_aa (n=5331260, bins=50) ===
#   Range:      [0, 105.964]
#   Mean:       0.425317,  Median: 0.0849633,  Std: 1.16469
#   Skewness:   11.3376,  Kurtosis: 408.6663  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0, Q95=1.89156, Q99=5.37303
#   Extreme:    5.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 2.1193, 4.2386, 6.3578, 8.4771]
#             bin_edges (last 5):  [97.4868, 99.6061, 101.7253, 103.8446, 105.9639]
#   Histogram counts (first 5):    [5102521, 145074, 46363, 18465, 8467]
#             counts (last 5):     [0, 0, 0, 0, 20]
#   Histogram count_sum: 5331260,  count_min: 0,  count_max: 5102521
#
# === feature_ab (n=5331052, bins=50) ===
#   Range:      [0, 41.4612]
#   Mean:       0.522453,  Median: 0.102999,  Std: 1.37283
#   Skewness:   6.2503,  Kurtosis: 63.6071  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0.00180229, Q95=2.75149, Q99=6.87082
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 0.8292, 1.6584, 2.4877, 3.3169]
#             bin_edges (last 5):  [38.1443, 38.9735, 39.8027, 40.632, 41.4612]
#   Histogram counts (first 5):    [4635518, 272352, 127342, 82663, 59520]
#             counts (last 5):     [0, 0, 60, 0, 5]
#   Histogram count_sum: 5331052,  count_min: 0,  count_max: 4635518
#
# === feature_ac (n=5330292, bins=50) ===
#   Range:      [0, 41.2452]
#   Mean:       0.432067,  Median: 0.0605762,  Std: 1.17394
#   Skewness:   8.9594,  Kurtosis: 161.7511  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.00163632, Q05=0.00431231, Q95=2.32366, Q99=5.04669
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 0.8249, 1.6498, 2.4747, 3.2996]
#             bin_edges (last 5):  [37.9456, 38.7705, 39.5954, 40.4203, 41.2452]
#   Histogram counts (first 5):    [4629637, 279301, 178934, 99542, 55214]
#             counts (last 5):     [40, 60, 80, 0, 40]
#   Histogram count_sum: 5330292,  count_min: 0,  count_max: 4629637
#
# === feature_ad (n=5328508, bins=50) ===
#   Range:      [0, 26.2574]
#   Mean:       0.675541,  Median: 0.0383969,  Std: 1.40247
#   Skewness:   3.4886,  Kurtosis: 19.1572  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.000621063, Q05=0.00196395, Q95=3.60906, Q99=6.50644
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 0.5251, 1.0503, 1.5754, 2.1006]
#             bin_edges (last 5):  [24.1568, 24.6819, 25.2071, 25.7322, 26.2574]
#   Histogram counts (first 5):    [3917882, 336726, 253257, 210945, 155390]
#             counts (last 5):     [0, 0, 0, 8, 16]
#   Histogram count_sum: 5328508,  count_min: 0,  count_max: 3917882
#
# === feature_ae (n=5329288, bins=50) ===
#   Range:      [0, 199.708]
#   Mean:       1.20191,  Median: 0.0141707,  Std: 5.25123
#   Skewness:   9.5621,  Kurtosis: 140.2581  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=1.6564e-05, Q05=0.000121776, Q95=5.60126, Q99=25.4448
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 3.9942, 7.9883, 11.9825, 15.9767]
#             bin_edges (last 5):  [183.7315, 187.7257, 191.7198, 195.714, 199.7082]
#   Histogram counts (first 5):    [5004894, 112056, 61562, 43931, 27004]
#             counts (last 5):     [0, 15, 15, 0, 15]
#   Histogram count_sum: 5329288,  count_min: 0,  count_max: 5004894
#
# === feature_af (n=5329288, bins=50) ===
#   Range:      [0.000423414, 2353.67]
#   Mean:       28.7893,  Median: 0.212914,  Std: 129.627
#   Skewness:   6.0574,  Kurtosis: 41.3605  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.00116585, Q05=0.00239699, Q95=50.2539, Q99=744.277
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0004, 47.0737, 94.147, 141.2203, 188.2936]
#             bin_edges (last 5):  [2165.3721, 2212.4454, 2259.5187, 2306.592, 2353.6653]
#   Histogram counts (first 5):    [5047466, 84290, 3440, 295, 480]
#             counts (last 5):     [0, 0, 40, 0, 80]
#   Histogram count_sum: 5329288,  count_min: 0,  count_max: 5047466
#
# === feature_ag (n=5329288, bins=50) ===
#   Range:      [0, 771.312]
#   Mean:       1.23368,  Median: 0.000125206,  Std: 9.85643
#   Skewness:   22.0047,  Kurtosis: 801.1221  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=5.02198e-09, Q05=4.78724e-08, Q95=2.88183, Q99=30.0435
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 15.4262, 30.8525, 46.2787, 61.7049]
#             bin_edges (last 5):  [709.6067, 725.0329, 740.4592, 755.8854, 771.3116]
#   Histogram counts (first 5):    [5223700, 54092, 19575, 11791, 6022]
#             counts (last 5):     [0, 5, 0, 20, 2]
#   Histogram count_sum: 5329288,  count_min: 0,  count_max: 5223700
#
# === feature_ah (n=5331260, bins=50) ===
#   Range:      [0, 15.6389]
#   Mean:       2.33213,  Median: 0.76142,  Std: 3.21162
#   Skewness:   1.7563,  Kurtosis: 2.5138  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.0111811, Q05=0.0261338, Q95=9.46524, Q99=13.242
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 0.3128, 0.6256, 0.9383, 1.2511]
#             bin_edges (last 5):  [14.3877, 14.7005, 15.0133, 15.3261, 15.6389]
#   Histogram counts (first 5):    [1896163, 623927, 302141, 245924, 204140]
#             counts (last 5):     [5182, 6160, 7093, 8199, 7154]
#   Histogram count_sum: 5331260,  count_min: 3764,  count_max: 1896163
#
# === feature_ai (n=5337414, bins=50) ===
#   Range:      [0.00262525, 42.7666]
#   Mean:       1.94086,  Median: 1.85511,  Std: 1.58828
#   Skewness:   1.1465,  Kurtosis: 5.8438  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.0273209, Q05=0.0892769, Q95=4.62952, Q99=6.34145
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0026, 0.8579, 1.7132, 2.5685, 3.4237]
#             bin_edges (last 5):  [39.3455, 40.2008, 41.0561, 41.9114, 42.7666]
#   Histogram counts (first 5):    [1841313, 660334, 1028993, 926981, 492732]
#             counts (last 5):     [0, 0, 0, 0, 15]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 1841313
#
# === feature_aj (n=5329288, bins=50) ===
#   Range:      [0.00572974, 41.2792]
#   Mean:       0.901724,  Median: 0.1121,  Std: 1.44656
#   Skewness:   2.8075,  Kurtosis: 16.1074  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.017474, Q05=0.0280976, Q95=3.84196, Q99=5.93215
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0057, 0.8312, 1.6567, 2.4821, 3.3076]
#             bin_edges (last 5):  [37.9773, 38.8028, 39.6283, 40.4537, 41.2792]
#   Histogram counts (first 5):    [3669872, 474073, 478628, 313536, 180803]
#             counts (last 5):     [0, 0, 0, 0, 5]
#   Histogram count_sum: 5329288,  count_min: 0,  count_max: 3669872
#
# === feature_ak (n=5329288, bins=50) ===
#   Range:      [0, 28.3922]
#   Mean:       0.164434,  Median: 0.0814588,  Std: 0.34302
#   Skewness:   19.2182,  Kurtosis: 849.8014  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.000125129, Q05=0.000391372, Q95=0.574547, Q99=1.26899
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 0.5678, 1.1357, 1.7035, 2.2714]
#             bin_edges (last 5):  [26.1209, 26.6887, 27.2566, 27.8244, 28.3922]
#   Histogram counts (first 5):    [5057117, 202781, 44534, 12586, 4762]
#             counts (last 5):     [20, 0, 0, 0, 20]
#   Histogram count_sum: 5329288,  count_min: 0,  count_max: 5057117
#
# === feature_al (n=5111998, bins=50) ===
#   Range:      [-343.122, 614.79]
#   Mean:       -0.102031,  Median: -0.000202309,  Std: 10.6081
#   Skewness:   4.4392,  Kurtosis: 260.1165  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-26.3276, Q05=-5.3465, Q95=3.69412, Q99=25.96
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-343.1223, -323.9641, -304.8058, -285.6476, -266.4893]
#             bin_edges (last 5):  [538.1569, 557.3151, 576.4733, 595.6316, 614.7898]
#   Histogram counts (first 5):    [5, 16, 19, 40, 64]
#             counts (last 5):     [4, 9, 4, 1, 3]
#   Histogram count_sum: 5111998,  count_min: 1,  count_max: 4647352
#
# === feature_am (n=5337414, bins=50) ===
#   Range:      [1.88096e-11, 864.131]
#   Mean:       13.6204,  Median: 1.12211,  Std: 36.2229
#   Skewness:   4.1091,  Kurtosis: 19.9636  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.00153428, Q05=0.00303372, Q95=87.3019, Q99=189.076
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 17.2826, 34.5652, 51.8479, 69.1305]
#             bin_edges (last 5):  [795.0006, 812.2832, 829.5658, 846.8485, 864.1311]
#   Histogram counts (first 5):    [4556411, 247619, 124634, 84388, 54799]
#             counts (last 5):     [0, 0, 8, 0, 8]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 4556411
#
# === feature_an (n=5337414, bins=50) ===
#   Range:      [3.05718e-10, 601.774]
#   Mean:       28.6547,  Median: 1.6508,  Std: 67.0003
#   Skewness:   3.1937,  Kurtosis: 10.5198  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.00316777, Q05=0.00553437, Q95=196.293, Q99=319.513
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 12.0355, 24.071, 36.1065, 48.1419]
#             bin_edges (last 5):  [553.6322, 565.6677, 577.7032, 589.7387, 601.7742]
#   Histogram counts (first 5):    [3703716, 548523, 269706, 67702, 55914]
#             counts (last 5):     [60, 20, 20, 20, 20]
#   Histogram count_sum: 5337414,  count_min: 20,  count_max: 3703716
#
# === feature_ao (n=5337414, bins=50) ===
#   Range:      [0.00105911, 945.285]
#   Mean:       31.2995,  Median: 0.89899,  Std: 82.2442
#   Skewness:   3.9753,  Kurtosis: 18.9599  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.0159604, Q05=0.0362743, Q95=204.009, Q99=421.943
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0011, 18.9067, 37.8124, 56.7181, 75.6238]
#             bin_edges (last 5):  [869.6627, 888.5684, 907.4741, 926.3798, 945.2855]
#   Histogram counts (first 5):    [4194590, 190562, 172949, 124956, 104140]
#             counts (last 5):     [100, 60, 80, 40, 40]
#   Histogram count_sum: 5337414,  count_min: 40,  count_max: 4194590
#
# === feature_ap (n=5337414, bins=50) ===
#   Range:      [0, 693.032]
#   Mean:       18.2474,  Median: 0.552619,  Std: 46.9709
#   Skewness:   4.0396,  Kurtosis: 18.8986  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.00323374, Q05=0.0101889, Q95=111.956, Q99=248.44
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 13.8606, 27.7213, 41.5819, 55.4425]
#             bin_edges (last 5):  [637.589, 651.4496, 665.3103, 679.1709, 693.0315]
#   Histogram counts (first 5):    [4023073, 448539, 257306, 125447, 83727]
#             counts (last 5):     [0, 4, 0, 0, 4]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 4023073
#
# === feature_aq (n=5337414, bins=50) ===
#   Range:      [0.0123179, 25.6168]
#   Mean:       1.50706,  Median: 0.784103,  Std: 1.64549
#   Skewness:   1.0049,  Kurtosis: 0.7181  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.0254388, Q05=0.039599, Q95=4.51226, Q99=6.21677
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0123, 0.5244, 1.0365, 1.5486, 2.0607]
#             bin_edges (last 5):  [23.5685, 24.0805, 24.5926, 25.1047, 25.6168]
#   Histogram counts (first 5):    [2635073, 179244, 263766, 323762, 376419]
#             counts (last 5):     [0, 0, 0, 0, 15]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 2635073
#
# === feature_ar (n=5337414, bins=50) ===
#   Range:      [0.00199526, 32.4075]
#   Mean:       1.20401,  Median: 0.603534,  Std: 1.41328
#   Skewness:   1.6191,  Kurtosis: 5.2031  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.0246721, Q05=0.0625631, Q95=4.13159, Q99=5.43702
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.002, 0.6501, 1.2982, 1.9463, 2.5944]
#             bin_edges (last 5):  [29.815, 30.4632, 31.1113, 31.7594, 32.4075]
#   Histogram counts (first 5):    [2702648, 518746, 831131, 449056, 275051]
#             counts (last 5):     [0, 0, 0, 0, 10]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 2702648
#
# === feature_as (n=5337414, bins=50) ===
#   Range:      [0.0221924, 22.9459]
#   Mean:       1.19629,  Median: 0.932597,  Std: 1.17837
#   Skewness:   1.3747,  Kurtosis: 4.6415  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.0429337, Q05=0.0654856, Q95=3.27015, Q99=4.84952
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0222, 0.4807, 0.9391, 1.3976, 1.8561]
#             bin_edges (last 5):  [21.112, 21.5704, 22.0289, 22.4874, 22.9459]
#   Histogram counts (first 5):    [2255822, 420370, 592272, 598649, 554046]
#             counts (last 5):     [0, 0, 0, 0, 15]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 2255822
#
# === feature_at (n=4671738, bins=50) ===
#   Range:      [0, 550471]
#   Mean:       3298.81,  Median: 13.7433,  Std: 13786.7
#   Skewness:   10.3187,  Kurtosis: 166.5180  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0, Q95=16375.8, Q99=60364.2
#   Extreme:    5.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 11009.4283, 22018.8565, 33028.2848, 44037.713]
#             bin_edges (last 5):  [506433.6996, 517443.1279, 528452.5561, 539461.9844, 550471.4126]
#   Histogram counts (first 5):    [4342164, 157648, 64139, 35520, 18857]
#             counts (last 5):     [0, 0, 0, 0, 20]
#   Histogram count_sum: 4671738,  count_min: 0,  count_max: 4342164
#
# === feature_au (n=5298967, bins=50) ===
#   Range:      [0, 994833]
#   Mean:       7266.75,  Median: 760.292,  Std: 25163.6
#   Skewness:   11.2767,  Kurtosis: 207.4590  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0, Q95=34116.4, Q99=103417
#   Extreme:    5.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 19896.6584, 39793.3168, 59689.9752, 79586.6335]
#             bin_edges (last 5):  [915246.2857, 935142.9441, 955039.6025, 974936.2609, 994832.9193]
#   Histogram counts (first 5):    [4854858, 224574, 91158, 44717, 26765]
#             counts (last 5):     [40, 20, 20, 20, 20]
#   Histogram count_sum: 5298967,  count_min: 0,  count_max: 4854858
#
# === feature_av (n=5298760, bins=50) ===
#   Range:      [0, 618352]
#   Mean:       5499.66,  Median: 747.929,  Std: 13633.7
#   Skewness:   6.2474,  Kurtosis: 69.2157  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0, Q95=27555.3, Q99=65135.9
#   Extreme:    5.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 12367.048, 24734.0961, 37101.1441, 49468.1921]
#             bin_edges (last 5):  [568884.2095, 581251.2575, 593618.3055, 605985.3536, 618352.4016]
#   Histogram counts (first 5):    [4657610, 336535, 135986, 68620, 39443]
#             counts (last 5):     [0, 0, 0, 0, 5]
#   Histogram count_sum: 5298760,  count_min: 0,  count_max: 4657610
#
# === feature_aw (n=5132220, bins=50) ===
#   Range:      [0, 787294]
#   Mean:       7069.57,  Median: 725.527,  Std: 20798.3
#   Skewness:   9.4815,  Kurtosis: 170.8077  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0, Q95=34911.5, Q99=91394.4
#   Extreme:    5.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 15745.8881, 31491.7762, 47237.6643, 62983.5524]
#             bin_edges (last 5):  [724310.853, 740056.7411, 755802.6292, 771548.5173, 787294.4054]
#   Histogram counts (first 5):    [4539245, 299538, 125448, 65650, 34542]
#             counts (last 5):     [55, 0, 125, 0, 40]
#   Histogram count_sum: 5132220,  count_min: 0,  count_max: 4539245
#
# === feature_ax (n=5299005, bins=50) ===
#   Range:      [0, 776179]
#   Mean:       9167.04,  Median: 1099.67,  Std: 22760.4
#   Skewness:   7.5912,  Kurtosis: 102.3902  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0, Q95=43537.1, Q99=98474.1
#   Extreme:    5.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 15523.5781, 31047.1561, 46570.7342, 62094.3123]
#             bin_edges (last 5):  [714084.5911, 729608.1692, 745131.7473, 760655.3254, 776178.9034]
#   Histogram counts (first 5):    [4414387, 442794, 205276, 99429, 50795]
#             counts (last 5):     [0, 0, 0, 0, 40]
#   Histogram count_sum: 5299005,  count_min: 0,  count_max: 4414387
#
# === feature_ay (n=4881494, bins=50) ===
#   Range:      [0, 600895]
#   Mean:       4322.41,  Median: 96.5784,  Std: 15602
#   Skewness:   8.8867,  Kurtosis: 118.9670  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0, Q95=21274, Q99=72800.4
#   Extreme:    5.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 12017.8931, 24035.7862, 36053.6793, 48071.5724]
#             bin_edges (last 5):  [552823.083, 564840.9761, 576858.8692, 588876.7623, 600894.6554]
#   Histogram counts (first 5):    [4464732, 201575, 80938, 44581, 24431]
#             counts (last 5):     [0, 0, 0, 0, 20]
#   Histogram count_sum: 4881494,  count_min: 0,  count_max: 4464732
#
# === feature_az (n=5326257, bins=50) ===
#   Range:      [0, 616.666]
#   Mean:       3.35633,  Median: 0.0962466,  Std: 10.5859
#   Skewness:   12.3194,  Kurtosis: 286.1086  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.000216638, Q05=0.00110196, Q95=17.5086, Q99=34.8025
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 12.3333, 24.6666, 37.0, 49.3333]
#             bin_edges (last 5):  [567.3328, 579.6661, 591.9995, 604.3328, 616.6661]
#   Histogram counts (first 5):    [4831384, 383099, 63242, 15793, 9100]
#             counts (last 5):     [1, 5, 1, 0, 2]
#   Histogram count_sum: 5326257,  count_min: 0,  count_max: 4831384
#
# === feature_ba (n=5337414, bins=50) ===
#   Range:      [0, 3.17545e+07]
#   Mean:       45269.7,  Median: 207.829,  Std: 361102
#   Skewness:   22.7175,  Kurtosis: 764.3002  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0, Q95=129465, Q99=843287
#   Extreme:    5.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 635089.5829, 1270179.1659, 1905268.7488, 2540358.3317]
#             bin_edges (last 5):  [29214120.8148, 29849210.3977, 30484299.9806, 31119389.5635, 31754479.1465]
#   Histogram counts (first 5):    [5271279, 28976, 13510, 6825, 4060]
#             counts (last 5):     [2, 0, 1, 0, 1]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 5271279
#
# === feature_bb (n=5337414, bins=50) ===
#   Range:      [0, 3.63053e+06]
#   Mean:       7172.93,  Median: 219.853,  Std: 33321.1
#   Skewness:   12.3677,  Kurtosis: 248.2062  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0, Q95=28395, Q99=139688
#   Extreme:    5.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 72610.6746, 145221.3492, 217832.0238, 290442.6984]
#             bin_edges (last 5):  [3340091.0318, 3412701.7064, 3485312.381, 3557923.0556, 3630533.7302]
#   Histogram counts (first 5):    [5226412, 60124, 23019, 11003, 7249]
#             counts (last 5):     [0, 0, 0, 0, 1]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 5226412
#
# === feature_bc (n=5337414, bins=50) ===
#   Range:      [0, 5.54253e+06]
#   Mean:       15129.3,  Median: 66.4762,  Std: 63638
#   Skewness:   12.9842,  Kurtosis: 322.6129  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0, Q95=75896, Q99=262415
#   Extreme:    5.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 110850.6385, 221701.2771, 332551.9156, 443402.5542]
#             bin_edges (last 5):  [5099129.3733, 5209980.0118, 5320830.6504, 5431681.2889, 5542531.9275]
#   Histogram counts (first 5):    [5156806, 110478, 34405, 15163, 7782]
#             counts (last 5):     [0, 0, 0, 0, 2]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 5156806
#
# === feature_bd (n=5337414, bins=50) ===
#   Range:      [0, 2.64497e+07]
#   Mean:       826199,  Median: 183476,  Std: 2.08048e+06
#   Skewness:   5.6104,  Kurtosis: 40.8139  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=649.432, Q05=4240.61, Q95=3.92148e+06, Q99=1.08822e+07
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 528994.1858, 1057988.3716, 1586982.5573, 2115976.7431]
#             bin_edges (last 5):  [24333732.5459, 24862726.7316, 25391720.9174, 25920715.1032, 26449709.289]
#   Histogram counts (first 5):    [3879358, 571031, 251709, 139271, 88535]
#             counts (last 5):     [685, 820, 775, 390, 195]
#   Histogram count_sum: 5337414,  count_min: 195,  count_max: 3879358
#
# === feature_be (n=5337414, bins=50) ===
#   Range:      [0, 1.07952e+07]
#   Mean:       522262,  Median: 126551,  Std: 980229
#   Skewness:   3.7897,  Kurtosis: 20.2929  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=1540.68, Q05=3595.11, Q95=2.44134e+06, Q99=4.70211e+06
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 215904.4924, 431808.9848, 647713.4772, 863617.9695]
#             bin_edges (last 5):  [9931606.6496, 10147511.142, 10363415.6344, 10579320.1268, 10795224.6192]
#   Histogram counts (first 5):    [3146205, 652404, 349255, 235602, 166832]
#             counts (last 5):     [440, 635, 1210, 830, 485]
#   Histogram count_sum: 5337414,  count_min: 278,  count_max: 3146205
#
# === feature_bf (n=5337414, bins=50) ===
#   Range:      [0, 1.0375e+07]
#   Mean:       401068,  Median: 83112.1,  Std: 822432
#   Skewness:   3.9083,  Kurtosis: 19.3900  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=876.61, Q05=2603.56, Q95=2.01127e+06, Q99=4.34505e+06
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 207499.3087, 414998.6174, 622497.9261, 829997.2348]
#             bin_edges (last 5):  [9544968.1999, 9752467.5086, 9959966.8173, 10167466.126, 10374965.4347]
#   Histogram counts (first 5):    [3474569, 589119, 337622, 234798, 146581]
#             counts (last 5):     [75, 35, 70, 76, 40]
#   Histogram count_sum: 5337414,  count_min: 35,  count_max: 3474569
#
# === feature_bg (n=5337414, bins=50) ===
#   Range:      [-0.00217442, 0.444578]
#   Mean:       0.0293884,  Median: 0.00456902,  Std: 0.0625002
#   Skewness:   2.6839,  Kurtosis: 6.6082  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-0.00116059, Q05=0, Q95=0.193862, Q99=0.283471
#   Extreme:    8.04% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-0.0022, 0.0068, 0.0157, 0.0246, 0.0336]
#             bin_edges (last 5):  [0.4088, 0.4178, 0.4267, 0.4356, 0.4446]
#   Histogram counts (first 5):    [3065971, 1004942, 228504, 114247, 77305]
#             counts (last 5):     [64, 0, 20, 36, 80]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 3065971
#
# === feature_bh (n=5337414, bins=50) ===
#   Range:      [0, 9.41271e+06]
#   Mean:       415358,  Median: 60597,  Std: 875395
#   Skewness:   4.1630,  Kurtosis: 22.7025  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=1591.6, Q05=3599.06, Q95=1.92462e+06, Q99=4.72537e+06
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 188254.2318, 376508.4636, 564762.6953, 753016.9271]
#             bin_edges (last 5):  [8659694.6617, 8847948.8935, 9036203.1252, 9224457.357, 9412711.5888]
#   Histogram counts (first 5):    [3550353, 417148, 260881, 202184, 159462]
#             counts (last 5):     [264, 60, 100, 120, 160]
#   Histogram count_sum: 5337414,  count_min: 60,  count_max: 3550353
#
# === feature_bi (n=5189982, bins=50) ===
#   Range:      [0, 66063.2]
#   Mean:       22.2085,  Median: 0.58755,  Std: 378.651
#   Skewness:   77.8665,  Kurtosis: 9230.4406  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0, Q95=39.3213, Q99=217.065
#   Extreme:    5.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 1321.2643, 2642.5286, 3963.7929, 5285.0572]
#             bin_edges (last 5):  [60778.1583, 62099.4226, 63420.687, 64741.9513, 66063.2156]
#   Histogram counts (first 5):    [5178008, 5799, 2388, 1222, 650]
#             counts (last 5):     [0, 20, 0, 0, 20]
#   Histogram count_sum: 5189982,  count_min: 0,  count_max: 5178008
#
# === feature_bj (n=5337374, bins=50) ===
#   Range:      [0, 1.24911e+06]
#   Mean:       9361.2,  Median: 735.132,  Std: 31236.4
#   Skewness:   8.9535,  Kurtosis: 130.1641  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0, Q95=45367, Q99=144532
#   Extreme:    5.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 24982.1567, 49964.3135, 74946.4702, 99928.627]
#             bin_edges (last 5):  [1149179.21, 1174161.3667, 1199143.5234, 1224125.6802, 1249107.8369]
#   Histogram counts (first 5):    [4862918, 234596, 93816, 48774, 28575]
#             counts (last 5):     [0, 0, 0, 0, 15]
#   Histogram count_sum: 5337374,  count_min: 0,  count_max: 4862918
#
# === feature_bk (n=5337414, bins=50) ===
#   Range:      [0, 3.56917e+06]
#   Mean:       16031.4,  Median: 1122.57,  Std: 47100.5
#   Skewness:   8.6926,  Kurtosis: 213.4390  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0, Q95=81436, Q99=230299
#   Extreme:    5.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 71383.307, 142766.6141, 214149.9211, 285533.2282]
#             bin_edges (last 5):  [3283632.124, 3355015.4311, 3426398.7381, 3497782.0452, 3569165.3522]
#   Histogram counts (first 5):    [5027892, 182846, 64499, 29804, 14962]
#             counts (last 5):     [0, 0, 0, 0, 20]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 5027892
#
# === feature_bl (n=5326257, bins=50) ===
#   Range:      [0, 766.111]
#   Mean:       6.27263,  Median: 0.0685182,  Std: 22.8033
#   Skewness:   5.5581,  Kurtosis: 39.0341  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.000101999, Q05=0.000701031, Q95=36.2379, Q99=126.065
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 15.3222, 30.6444, 45.9666, 61.2889]
#             bin_edges (last 5):  [704.8218, 720.144, 735.4662, 750.7885, 766.1107]
#   Histogram counts (first 5):    [4855947, 164495, 81860, 41938, 30340]
#             counts (last 5):     [0, 0, 0, 0, 1]
#   Histogram count_sum: 5326257,  count_min: 0,  count_max: 4855947
#
# === feature_bm (n=5337414, bins=50) ===
#   Range:      [2.34862e-06, 14871.1]
#   Mean:       511.657,  Median: 4.94942,  Std: 1573.51
#   Skewness:   4.5844,  Kurtosis: 23.2763  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.0048961, Q05=0.0168249, Q95=3067.16, Q99=9033.45
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 297.4218, 594.8435, 892.2653, 1189.6871]
#             bin_edges (last 5):  [13681.4013, 13978.8231, 14276.2448, 14573.6666, 14871.0884]
#   Histogram counts (first 5):    [4275979, 287787, 146408, 72899, 65074]
#             counts (last 5):     [356, 328, 248, 244, 164]
#   Histogram count_sum: 5337414,  count_min: 164,  count_max: 4275979
#
# === feature_bn (n=5337414, bins=50) ===
#   Range:      [2.07462e-07, 12887.8]
#   Mean:       570.82,  Median: 13.9866,  Std: 1525.67
#   Skewness:   3.8200,  Kurtosis: 15.4653  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.0520794, Q05=0.0940383, Q95=3751.26, Q99=7920.36
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 257.7561, 515.5122, 773.2682, 1031.0243]
#             bin_edges (last 5):  [11856.7796, 12114.5357, 12372.2918, 12630.0479, 12887.8039]
#   Histogram counts (first 5):    [3911541, 452218, 156853, 136493, 104381]
#             counts (last 5):     [320, 240, 40, 100, 80]
#   Histogram count_sum: 5337414,  count_min: 40,  count_max: 3911541
#
# === feature_bo (n=5337414, bins=50) ===
#   Range:      [0, 14238.2]
#   Mean:       399.155,  Median: 3.50847,  Std: 1421.88
#   Skewness:   5.2675,  Kurtosis: 29.6993  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.0137619, Q05=0.0575569, Q95=1431.01, Q99=8579.62
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 284.7642, 569.5284, 854.2927, 1139.0569]
#             bin_edges (last 5):  [13099.154, 13383.9182, 13668.6824, 13953.4466, 14238.2109]
#   Histogram counts (first 5):    [4384157, 136492, 176937, 207226, 163692]
#             counts (last 5):     [200, 320, 360, 200, 80]
#   Histogram count_sum: 5337414,  count_min: 80,  count_max: 4384157
#
# === feature_bp (n=5337414, bins=50) ===
#   Range:      [7.74974e-05, 148.377]
#   Mean:       1.78516,  Median: 0.569469,  Std: 3.41729
#   Skewness:   6.5273,  Kurtosis: 87.0778  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.000171428, Q05=0.00191256, Q95=6.88295, Q99=16.3485
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0001, 2.9676, 5.9351, 8.9027, 11.8702]
#             bin_edges (last 5):  [136.5064, 139.4739, 142.4415, 145.409, 148.3765]
#   Histogram counts (first 5):    [4389057, 607388, 172370, 67963, 34061]
#             counts (last 5):     [5, 2, 0, 0, 5]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 4389057
#
# === feature_bq (n=5337414, bins=50) ===
#   Range:      [2.8891e-05, 2407.61]
#   Mean:       9.99957,  Median: 0.176129,  Std: 51.7112
#   Skewness:   8.2091,  Kurtosis: 103.2157  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.000508096, Q05=0.000924985, Q95=9.28256, Q99=269.606
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 48.1522, 96.3043, 144.4564, 192.6085]
#             bin_edges (last 5):  [2214.9979, 2263.15, 2311.3022, 2359.4543, 2407.6064]
#   Histogram counts (first 5):    [5124218, 25122, 33260, 35465, 46810]
#             counts (last 5):     [2, 0, 0, 0, 4]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 5124218
#
# === feature_br (n=5337414, bins=50) ===
#   Range:      [0, 520.215]
#   Mean:       3.45873,  Median: 0.157391,  Std: 10.1391
#   Skewness:   7.4136,  Kurtosis: 89.9151  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.000169566, Q05=0.00048699, Q95=13.2859, Q99=51.2513
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 10.4043, 20.8086, 31.2129, 41.6172]
#             bin_edges (last 5):  [478.598, 489.0023, 499.4066, 509.8109, 520.2152]
#   Histogram counts (first 5):    [5011100, 124052, 57560, 54080, 38950]
#             counts (last 5):     [0, 0, 0, 0, 1]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 5011100
#
# === feature_bs (n=5337414, bins=50) ===
#   Range:      [-12.985, -0.0823753]
#   Mean:       -2.44816,  Median: -0.486311,  Std: 3.06431
#   Skewness:   -1.3324,  Kurtosis: 0.7217  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-11.703, Q05=-9.86507, Q95=-0.122046, Q99=-0.110581
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-12.985, -12.7269, -12.4689, -12.2108, -11.9528]
#             bin_edges (last 5):  [-1.1146, -0.8565, -0.5985, -0.3404, -0.0824]
#   Histogram counts (first 5):    [2, 27, 437, 5450, 49118]
#             counts (last 5):     [0, 0, 2, 2356994, 883613]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 2356994
#
# === feature_bt (n=5337414, bins=50) ===
#   Range:      [-10.9839, -0.0378793]
#   Mean:       -2.37747,  Median: -1.54917,  Std: 2.36989
#   Skewness:   -0.5701,  Kurtosis: -0.9975  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-7.21316, Q05=-6.98768, Q95=-0.0953239, Q99=-0.0876493
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-10.9839, -10.765, -10.5461, -10.3272, -10.1083]
#             bin_edges (last 5):  [-0.9136, -0.6946, -0.4757, -0.2568, -0.0379]
#   Histogram counts (first 5):    [4, 0, 0, 0, 5]
#             counts (last 5):     [34, 8, 0, 250536, 2212498]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 2212498
#
# === feature_bu (n=5337414, bins=50) ===
#   Range:      [-7.74873, 0]
#   Mean:       -2.13199,  Median: -2.84023,  Std: 1.59617
#   Skewness:   0.2414,  Kurtosis: -1.6595  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-4.2709, Q05=-4.05827, Q95=-0.0615731, Q99=-0.0596223
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-7.7487, -7.5938, -7.4388, -7.2838, -7.1288]
#             bin_edges (last 5):  [-0.6199, -0.4649, -0.3099, -0.155, 0.0]
#   Histogram counts (first 5):    [4, 0, 0, 0, 0]
#             counts (last 5):     [74552, 307, 2, 255705, 1486538]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 1486538
#
# === feature_bv (n=5337414, bins=50) ===
#   Range:      [2.60125e-07, 7.01792]
#   Mean:       0.999352,  Median: 0.145188,  Std: 1.29248
#   Skewness:   1.1247,  Kurtosis: -0.2439  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.0327089, Q05=0.0357583, Q95=3.72604, Q99=3.99912
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 0.1404, 0.2807, 0.4211, 0.5614]
#             bin_edges (last 5):  [6.4565, 6.5968, 6.7372, 6.8776, 7.0179]
#   Histogram counts (first 5):    [2489139, 766999, 5, 27, 929]
#             counts (last 5):     [0, 0, 4, 0, 4]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 2489139
#
# === feature_bw (n=5337414, bins=50) ===
#   Range:      [4.05681e-08, 10.1029]
#   Mean:       1.85876,  Median: 0.261639,  Std: 2.2347
#   Skewness:   0.9129,  Kurtosis: -0.6824  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.0879829, Q05=0.0931003, Q95=6.37125, Q99=6.81795
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 0.2021, 0.4041, 0.6062, 0.8082]
#             bin_edges (last 5):  [9.2947, 9.4967, 9.6988, 9.9009, 10.1029]
#   Histogram counts (first 5):    [1854858, 1078443, 4, 0, 539]
#             counts (last 5):     [2, 0, 8, 1, 4]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 1854858
#
# === feature_bx (n=5337414, bins=50) ===
#   Range:      [0.123495, 13.1443]
#   Mean:       4.58416,  Median: 4.60726,  Std: 4.00481
#   Skewness:   0.2841,  Kurtosis: -1.3819  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.174173, Q05=0.211386, Q95=10.9016, Q99=11.565
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.1235, 0.3839, 0.6443, 0.9047, 1.1652]
#             bin_edges (last 5):  [12.1026, 12.363, 12.6235, 12.8839, 13.1443]
#   Histogram counts (first 5):    [1801394, 264052, 0, 0, 0]
#             counts (last 5):     [12939, 1109, 94, 11, 3]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 1801394
#
# === feature_by (n=4749274, bins=50) ===
#   Range:      [-30.223, -1.67942e-09]
#   Mean:       -0.0812105,  Median: -0.00506536,  Std: 0.317121
#   Skewness:   -16.2443,  Kurtosis: 592.4109  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-1.31246, Q05=-0.344173, Q95=-5.04073e-05, Q99=-1.95299e-05
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-30.223, -29.6186, -29.0141, -28.4096, -27.8052]
#             bin_edges (last 5):  [-2.4178, -1.8134, -1.2089, -0.6045, -0.0]
#   Histogram counts (first 5):    [5, 0, 0, 0, 0]
#             counts (last 5):     [5968, 11940, 28135, 66839, 4627716]
#   Histogram count_sum: 4749274,  count_min: 0,  count_max: 4627716
#
# === feature_bz (n=5185692, bins=50) ===
#   Range:      [-55.486, -9.03473e-06]
#   Mean:       -0.164488,  Median: -0.011312,  Std: 0.736904
#   Skewness:   -11.5054,  Kurtosis: 283.4691  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-3.55396, Q05=-0.46604, Q95=-8.10831e-05, Q99=-1.83108e-05
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-55.486, -54.3763, -53.2666, -52.1569, -51.0472]
#             bin_edges (last 5):  [-4.4389, -3.3292, -2.2195, -1.1097, -0.0]
#   Histogram counts (first 5):    [5, 0, 5, 1, 0]
#             counts (last 5):     [13023, 26097, 56077, 85190, 4986181]
#   Histogram count_sum: 5185692,  count_min: 0,  count_max: 4986181
#
# === feature_ca (n=5337374, bins=50) ===
#   Range:      [-93.1141, 0]
#   Mean:       -0.281113,  Median: -0.0130639,  Std: 1.08178
#   Skewness:   -10.5789,  Kurtosis: 289.7208  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-4.9492, Q05=-2.04093, Q95=-5.37552e-05, Q99=-1.8612e-05
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-93.1141, -91.2519, -89.3896, -87.5273, -85.665]
#             bin_edges (last 5):  [-7.4491, -5.5868, -3.7246, -1.8623, 0.0]
#   Histogram counts (first 5):    [5, 0, 0, 0, 0]
#             counts (last 5):     [7591, 20655, 69235, 177720, 5052346]
#   Histogram count_sum: 5337374,  count_min: 0,  count_max: 5052346
#
# === feature_cb (n=5337414, bins=50) ===
#   Range:      [-36.9033, -1.73381e-10]
#   Mean:       -0.178131,  Median: -0.0172756,  Std: 0.528113
#   Skewness:   -8.8787,  Kurtosis: 176.4818  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-2.52237, Q05=-0.92359, Q95=-2.85711e-05, Q99=-1.36743e-05
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-36.9033, -36.1653, -35.4272, -34.6891, -33.9511]
#             bin_edges (last 5):  [-2.9523, -2.2142, -1.4761, -0.7381, -0.0]
#   Histogram counts (first 5):    [5, 0, 0, 0, 0]
#             counts (last 5):     [16773, 32812, 77493, 181460, 5009284]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 5009284
#
# === feature_cc (n=5334779, bins=50) ===
#   Range:      [-134.674, -9.19516e-11]
#   Mean:       -0.460958,  Median: -0.013166,  Std: 1.66786
#   Skewness:   -9.3360,  Kurtosis: 232.6307  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-7.52973, Q05=-3.41745, Q95=-8.3934e-05, Q99=-6.12965e-06
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-134.6736, -131.9802, -129.2867, -126.5932, -123.8998]
#             bin_edges (last 5):  [-10.7739, -8.0804, -5.3869, -2.6935, -0.0]
#   Histogram counts (first 5):    [5, 0, 0, 0, 0]
#             counts (last 5):     [9075, 24128, 79530, 209427, 5001833]
#   Histogram count_sum: 5334779,  count_min: 0,  count_max: 5001833
#
# === feature_cd (n=4937300, bins=50) ===
#   Range:      [-247.59, 4.88488e-05]
#   Mean:       -0.82394,  Median: -0.00156806,  Std: 3.24358
#   Skewness:   -10.4429,  Kurtosis: 251.0665  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-15.0209, Q05=-4.81663, Q95=-0.000138386, Q99=-5.55896e-05
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-247.5901, -242.6383, -237.6865, -232.7347, -227.7829]
#             bin_edges (last 5):  [-19.8072, -14.8554, -9.9036, -4.9518, 0.0]
#   Histogram counts (first 5):    [5, 0, 0, 5, 0]
#             counts (last 5):     [12324, 22814, 54176, 136373, 4696294]
#   Histogram count_sum: 4937300,  count_min: 0,  count_max: 4696294
#
# === feature_ce (n=5061585, bins=50) ===
#   Range:      [-7.68457, 2.64211]
#   Mean:       -0.0228815,  Median: -0.00188656,  Std: 0.172899
#   Skewness:   -8.3834,  Kurtosis: 232.3465  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-0.515831, Q05=-0.249436, Q95=0.151775, Q99=0.36321
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-7.6846, -7.478, -7.2715, -7.065, -6.8584]
#             bin_edges (last 5):  [1.816, 2.0225, 2.229, 2.4356, 2.6421]
#   Histogram counts (first 5):    [135, 0, 0, 0, 0]
#             counts (last 5):     [40, 20, 0, 0, 20]
#   Histogram count_sum: 5061585,  count_min: 0,  count_max: 3561943
#
# === feature_cf (n=5101025, bins=50) ===
#   Range:      [0.0061282, 13.6349]
#   Mean:       1.47268,  Median: 1.19716,  Std: 1.49199
#   Skewness:   0.8981,  Kurtosis: 0.2718  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.0224484, Q05=0.0419922, Q95=4.24229, Q99=5.6354
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0061, 0.2787, 0.5513, 0.8239, 1.0964]
#             bin_edges (last 5):  [12.5446, 12.8172, 13.0898, 13.3623, 13.6349]
#   Histogram counts (first 5):    [2186880, 33022, 24499, 170741, 376117]
#             counts (last 5):     [20, 20, 0, 0, 20]
#   Histogram count_sum: 5101025,  count_min: 0,  count_max: 2186880
#
# === feature_cg (n=5297770, bins=50) ===
#   Range:      [0.0160653, 10.5644]
#   Mean:       1.06279,  Median: 0.15947,  Std: 1.30398
#   Skewness:   1.1947,  Kurtosis: 0.7994  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.0232515, Q05=0.0327403, Q95=3.57962, Q99=4.99359
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0161, 0.227, 0.438, 0.649, 0.8599]
#             bin_edges (last 5):  [9.7205, 9.9315, 10.1425, 10.3534, 10.5644]
#   Histogram counts (first 5):    [2918566, 73621, 140097, 34983, 15917]
#             counts (last 5):     [0, 60, 0, 0, 20]
#   Histogram count_sum: 5297770,  count_min: 0,  count_max: 2918566
#
# === feature_ch (n=5337414, bins=50) ===
#   Range:      [0, 10]
#   Mean:       2.32343,  Median: 2,  Std: 2.09297
#   Skewness:   1.2052,  Kurtosis: 1.1897  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0, Q05=0, Q95=7, Q99=9
#   Extreme:    3.74% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 0.2, 0.4, 0.6, 0.8]
#             bin_edges (last 5):  [9.2, 9.4, 9.6, 9.8, 10.0]
#   Histogram counts (first 5):    [984511, 0, 0, 0, 0]
#             counts (last 5):     [89584, 0, 0, 0, 20]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 1262940
#
# === y_target (n=5337414, bins=50) ===
#   Range:      [-2201.88, 2314.41]
#   Mean:       -0.665905,  Median: -0.000577482,  Std: 32.5276
#   Skewness:   1.1886,  Kurtosis: 289.7649  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=-82.7972, Q05=-7.60681, Q95=4.50475, Q99=62.9234
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [-2201.8816, -2111.5557, -2021.2299, -1930.904, -1840.5782]
#             bin_edges (last 5):  [1953.1077, 2043.4336, 2133.7594, 2224.0853, 2314.4112]
#   Histogram counts (first 5):    [1, 0, 0, 0, 0]
#             counts (last 5):     [0, 1, 1, 0, 2]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 5168463
#
# === weight (n=5337414, bins=50) ===
#   Range:      [0, 1.39122e+13]
#   Mean:       1.64279e+07,  Median: 1699.38,  Std: 6.02707e+09
#   Skewness:   2304.3863,  Kurtosis: 5318962.5871  (skew>0 → right tail; kurt>0 → heavy tails)
#   Quantiles:  Q01=0.00316297, Q05=0.0165551, Q95=4.31707e+07, Q99=3.03841e+08
#   Extreme:    10.00% outside [Q05, Q95]
#   Histogram bin_edges (first 5): [0.0, 278244355666.6627, 556488711333.3254, 834733066999.9882, 1112977422666.651]
#             bin_edges (last 5):  [12799240360666.484, 13077484716333.148, 13355729071999.81, 13633973427666.473, 13912217783333.135]
#   Histogram counts (first 5):    [5337412, 1, 0, 0, 0]
#             counts (last 5):     [0, 0, 0, 0, 1]
#   Histogram count_sum: 5337414,  count_min: 0,  count_max: 5337412

# %%
# import matplotlib.pyplot as plt

# # Loop over columns and plot histograms for each
# for col in pdf.columns:
#     data = pdf[col].dropna()
#     plt.figure()
#     if pd.api.types.is_numeric_dtype(data):
#         plt.hist(data, bins=50)
#         plt.xlabel(col)
#         plt.ylabel("Frequency")
#         plt.title(f"Histogram of {col}")
#         plt.show()
#     else:
#         # Only plot histogram for numeric columns
#         continue
